# %% [markdown]
# # ML Internship Assignment - Run in Google Colab
#
# This notebook sets up and runs the ML internship assignment project in Google Colab.

# %% [markdown]
# ## 1. Install Required Libraries
#
# Install the necessary libraries from requirements.txt.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Mount Google Drive
#
# Mount Google Drive to access project files.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Change to the project directory (adjust path as needed)
import os
os.chdir('/content/drive/My Drive/MLinternAssignement')  # Adjust this path

# %% [markdown]
# ## 3. Set Up Colab Environment
#
# Configure the Colab environment.

# %%
# Check GPU availability
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Set random seeds for reproducibility
import random
import numpy as np
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# %% [markdown]
# ## 4. Run and Verify Code Execution
#
# Execute the main scripts and verify they run correctly.

# %%
# Run data generation
# !python part_a/generate_dataset.py

# Run data cleaning
# !python part_a/clean_data.py

# Check if files were created
import os
print("Files created:")
for root, dirs, files in os.walk('.'):
    for file in files:
        if file.endswith('.jsonl') or file.endswith('.png'):
            print(os.path.join(root, file))

# Run the Streamlit app (in Colab, use ngrok or similar for external access)
# For demo, just import and test
import demo
print("Demo module imported successfully")

# %% [markdown]
# ## Run the Streamlit App
#
# To run the Streamlit app in Colab, use the following command. Note that Colab may require additional setup for external access.

# %%
# Install ngrok for external access (optional)
# !pip install pyngrok
# from pyngrok import ngrok
# public_url = ngrok.connect(port='8501')
# print(public_url)

# Run Streamlit app
# !streamlit run demo.py --server.port 8501 --server.address 0.0.0.0
